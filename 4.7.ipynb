# %%
# 本体不再给python解，参见4.5题
# 题：解下列方程组，并用 ezmesh 函数画出各个方程所对应的平面、交线及交点。
#  (a) close, ezmesh('(x+3*y-5)/2'),hold on,ezmesh('-3*x+y+2'),hold on, ezmesh('(2*x+y+3)/3') 
#  (b) close, ezmesh('(x+3*y-5)/2'),hold on,ezmesh('-3*x+y+2'),hold on, ezmesh('(2*x+6*y-3)/4')

# malab效果预览：
from PIL import Image
display(Image.open('4.7a-matlab.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=560x420 at 0x29E4822A340>

# %%
display(Image.open('4.7b-matlab.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=560x420 at 0x29E4839F610>
